# %%
#####TIC TAC TOE Game#############AJJAY GAADHE###############################
flag=0
list2=[]
list1=['0','1','2','3','4','5','6','7','8']
d={'player1':'X','player2':'O'} ###Assigning Symbol for player 1 and Player 2
checkval=1

def check(pos):
    if pos in list2:
        print('invalid option Try Again')
        checkval=0
        return checkval
                
    else:
        #list2.append(pos)
        checkval=1 
        return checkval
def player1():
    pos_X= int(input('Player one select position: '))
    if pos_X >=9:
        print ("Invalid Input position")
    checkval=check(pos_X)
    #print(f'checkvalue is {checkval}')
    if checkval==0:
        flag=0
        flag=player1()
        return flag
    else:
        list2.append(pos_X)
        list1[pos_X]=d['player1']
        print(f'{list1[6]} || {list1[7]} || {list1[8]}')
        print(f'{list1[3]} || {list1[4]} || {list1[5]}')
        print(f'{list1[0]} || {list1[1]} || {list1[2]}')
        flag=1
        print(list2)
        if (list1[1]==list1[2]==list1[0] or list1[4]==list1[5]==list1[3] 
            or list1[7]==list1[8]==list1[6]or list1[1]==list1[4]==list1[7] 
            or list1[5]==list1[2]==list1[8] or list1[3]==list1[6]==list1[0]
            or list1[0]==list1[4]==list1[8] or list1[6]==list1[4]==list1[2]):
            print('Player 1 won')
            flag=3
        return flag
        
        
def player2():
    pos_O= int(input('Player two select position: '))
    if pos_O >=9:
        print ("Invalid Input position")
    checkval=check(pos_O)
    if checkval==0:
        flag=player2()
        return flag
    else:
        
        list2.append(pos_O)
        list1[pos_O]=d['player2']
        print(f'{list1[6]} || {list1[7]} || {list1[8]}')
        print(f'{list1[3]} || {list1[4]} || {list1[5]}')
        print(f'{list1[0]} || {list1[1]} || {list1[2]}')
        flag=0
        print(list2)
        
        if (list1[1]==list1[2]==list1[0] or list1[4]==list1[5]==list1[3] 
            or list1[7]==list1[8]==list1[6]or list1[1]==list1[4]==list1[7] 
            or list1[5]==list1[2]==list1[8] or list1[3]==list1[6]==list1[0]
            or list1[0]==list1[4]==list1[8] or list1[6]==list1[4]==list1[2]):
            print('Player 2 won')
            flag=3
        
        return flag


for count in range(1,10):
    if flag==0:
        flag=player1()
        print(f'value of flag is : {flag}')
        if flag==3:
            break
       # print('return')
    elif flag==1:
        flag=player2()
        print(f'value of flag is : {flag}')
        if flag==3:
            break
# Out:
# Player one select position: 1
# 6 || 7 || 8
# 3 || 4 || 5
# 0 || X || 2
# [1]
# value of flag is : 1
# Player two select position: 2
# 6 || 7 || 8
# 3 || 4 || 5
# 0 || X || O
# [1, 2]
# value of flag is : 0
# Player one select position: 3
# 6 || 7 || 8
# X || 4 || 5
# 0 || X || O
# [1, 2, 3]
# value of flag is : 1
# Player two select position: 4
# 6 || 7 || 8
# X || O || 5
# 0 || X || O
# [1, 2, 3, 4]
# value of flag is : 0
# Player one select position: 5
# 6 || 7 || 8
# X || O || X
# 0 || X || O
# [1, 2, 3, 4, 5]
# value of flag is : 1
# Player two select position: 6
# O || 7 || 8
# X || O || X
# 0 || X || O
# [1, 2, 3, 4, 5, 6]
# Player 2 won
# value of flag is : 3
